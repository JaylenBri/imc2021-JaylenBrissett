# %%
# import libraries
import numpy as np
import matplotlib.pylab as plt
import librosa
import librosa.display

# %%
# Open the audio file avm2.wav with librosa.load()
file = 'avm2.wav'
sig , sr = librosa.load(file,mono=True,sr=None)

# %%
# Plot a time-domain representation of the signal with matplotlib
plt.plot(sig)

# %%
# Adjust the x-axis to represent time
time=np.arange(0,sig.shape[0])/sr
plt.plot(time,sig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-548ccf9add2d> in <module>
#       1 # Adjust the x-axis to represent time
# ----> 2 time=np.arange(0,sig.shape[0])/sr
#       3 plt.plot(time,sig)
#
# NameError: name 'np' is not defined

# %%
# Scale the y-axis to represent amplitude
excursion=max(abs(sig))
sigNew = sig / excursion
plt.plot(time,sigNew)

# %%
# Label the x and y axes
plt.plot(time,sigNew)
plt.xlabel('Time (seconds)')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')
